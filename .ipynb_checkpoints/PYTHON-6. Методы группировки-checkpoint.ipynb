# %%
import pandas as pd
df=pd.read_csv('C:\\Users\\user\\Documents\\DataScience\\PYTHON\\data_sf.csv')

# %%
small_df = df[df.columns[1:8]].head(25)
small_df
# Out:
#                  Name  Age Nationality                 Club      Value  \
# 0            L. Messi   31   Argentina         FC Barcelona  110500000
# 1   Cristiano Ronaldo   33    Portugal             Juventus   77000000
# 2           Neymar Jr   26      Brazil  Paris Saint-Germain  118500000
# 3              De Gea   27       Spain    Manchester United   72000000
# 4        K. De Bruyne   27     Belgium      Manchester City  102000000
# 5           E. Hazard   27     Belgium              Chelsea   93000000
# 6           L. Modrić   32     Croatia          Real Madrid   67000000
# 7           L. Suárez   31     Uruguay         FC Barcelona   80000000
# 8        Sergio Ramos   32       Spain          Real Madrid   51000000
# 9            J. Oblak   25    Slovenia      Atlético Madrid   68000000
# 10     R. Lewandowski   29      Poland    FC Bayern München   77000000
# 11           T. Kroos   28     Germany          Real Madrid   76500000
# ...

# %%
s = small_df['Nationality'].value_counts()
display(s)
# Out:
# Spain        4
# Argentina    3
# Uruguay      3
# Belgium      3
# Germany      3
# France       2
# Brazil       1
# Poland       1
# Portugal     1
# Slovenia     1
# England      1
# Croatia      1
# Italy        1
# Name: Nationality, dtype: int64

# %%
s.index
# Out:
# Index(['Spain', 'Argentina', 'Uruguay', 'Belgium', 'Germany', 'France',
#        'Brazil', 'Poland', 'Portugal', 'Slovenia', 'England', 'Croatia',
#        'Italy'],
#       dtype='object')

# %%
s['Germany']
# Out:
# 3

# %%
s.loc[s > 1]
# Out:
# Spain        4
# Argentina    3
# Uruguay      3
# Belgium      3
# Germany      3
# France       2
# Name: Nationality, dtype: int64

# %%
s.loc[s > 2]
# Out:
# Spain        4
# Argentina    3
# Uruguay      3
# Belgium      3
# Germany      3
# Name: Nationality, dtype: int64

# %%
c = df['Club'].value_counts()
c
# Out:
# Shonan Bellmare      30
# V-Varen Nagasaki     30
# Vissel Kobe          29
# De Graafschap        29
# Padova               29
#                      ..
# Olympiacos CFP        8
# GD Chaves             7
# Vitória Guimarães     7
# Dinamo Zagreb         7
# Atlético Mineiro      6
# Name: Club, Length: 650, dtype: int64

# %%
len(c.index)
# Out:
# 10

# %%
p = df['Position'].value_counts(normalize=True)
display(p)
# Out:
# GK     0.127239
# ST     0.117237
# CB     0.108785
# CM     0.082732
# LB     0.077692
# RB     0.073505
# RM     0.059394
# LM     0.056447
# CDM    0.053578
# CAM    0.049081
# RCB    0.032411
# LCB    0.031713
# LW     0.018764
# RCM    0.018609
# RW     0.018376
# LCM    0.018066
# LDM    0.011476
# RDM    0.010700
# LS     0.009382
# RS     0.008839
# RWB    0.005428
# LWB    0.004652
# CF     0.003954
# LF     0.000620
# RF     0.000465
# LAM    0.000465
# RAM    0.000388
# Name: Position, dtype: float64

# %%
s = small_df['Age'].value_counts()
display(s)
# Out:
# 27    5
# 32    5
# 31    3
# 26    3
# 29    2
# 24    2
# 33    2
# 30    1
# 28    1
# 25    1
# Name: Age, dtype: int64

# %%
s = small_df['Wage'].value_counts()
display(s)
# Out:
# 205000    3
# 355000    2
# 240000    2
# 300000    1
# 130000    1
# 225000    1
# 455000    1
# 340000    1
# 315000    1
# 565000    1
# 405000    1
# 215000    1
# 380000    1
# 285000    1
# 145000    1
# 290000    1
# 125000    1
# 200000    1
# 420000    1
# 94000     1
# 260000    1
# Name: Wage, dtype: int64

# %%
s = small_df['Wage'].value_counts(bins=4)
display(s)
# Out:
# (211750.0, 329500.0]     9
# (93528.999, 211750.0]    8
# (329500.0, 447250.0]     6
# (447250.0, 565000.0]     2
# Name: Wage, dtype: int64

# %%
(205000-260000)/5
# Out:
# -11000.0

# %%
small_df.loc[(small_df['Wage'] > s.index[3].left) & (small_df['Wage'] <= s.index[3].right)]
# Out:
#         Name  Age Nationality          Club      Value    Wage Position
# 0   L. Messi   31   Argentina  FC Barcelona  110500000  565000       RF
# 7  L. Suárez   31     Uruguay  FC Barcelona   80000000  455000       RS

# %%
small_df = df[df.columns[0:7]].head(25)
s = small_df['Wage'].value_counts(bins=4)
display(s)
small_df['Wage'] > s.index[3].left
# Out:
# (211750.0, 329500.0]     9
# (93528.999, 211750.0]    8
# (329500.0, 447250.0]     6
# (447250.0, 565000.0]     2
# Name: Wage, dtype: int64
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# Name: Wage, dtype: bool

# %%
p = df['FKAccuracy'].value_counts(normalize=True,bins=5)
display(p)
# Out:
# (21.2, 39.4]     0.376754
# (39.4, 57.6]     0.306816
# (57.6, 75.8]     0.163449
# (2.908, 21.2]    0.136466
# (75.8, 94.0]     0.016515
# Name: FKAccuracy, dtype: float64

# %%
import pandas as pd
df=pd.read_csv('C:\\Users\\user\\Documents\\DataScience\\PYTHON\\data_sf.csv')
small_df = df[df.columns[1:8]].head(25)
small_df
s = small_df['Nationality'].value_counts()
print(s.index)
print(len(s.index))
# Out:
# Index(['Spain', 'Germany', 'Argentina', 'Belgium', 'Uruguay', 'France',
#        'Poland', 'Portugal', 'Croatia', 'Slovenia', 'England', 'Brazil',
#        'Italy'],
#       dtype='object')
# 13

# %%
small_df['Nationality'].unique()
# Out:
# array(['Argentina', 'Portugal', 'Brazil', 'Spain', 'Belgium', 'Croatia',
#        'Uruguay', 'Slovenia', 'Poland', 'Germany', 'France', 'England',
#        'Italy'], dtype=object)

# %%
s = small_df['Nationality'].value_counts()
s_df = s.reset_index()
display(s_df)
# Out:
#         index  Nationality
# 0       Spain            4
# 1     Germany            3
# 2   Argentina            3
# 3     Belgium            3
# 4     Uruguay            3
# 5      France            2
# 6      Poland            1
# 7    Portugal            1
# 8     Croatia            1
# 9    Slovenia            1
# 10    England            1
# 11     Brazil            1
# 12      Italy            1

# %%
s_df.columns = ['Nationality','Players Count']
display(s_df)
# Out:
#    Nationality  Players Count
# 0        Spain              4
# 1      Germany              3
# 2    Argentina              3
# 3      Belgium              3
# 4      Uruguay              3
# 5       France              2
# 6       Poland              1
# 7     Portugal              1
# 8      Croatia              1
# 9     Slovenia              1
# 10     England              1
# 11      Brazil              1
# 12       Italy              1

# %%
df[df.Nationality == 'Spain']['Wage'].value_counts(normalize=True,bins=4)
# Out:
# (620.999, 95750.0]      0.970194
# (95750.0, 190500.0]     0.016393
# (190500.0, 285250.0]    0.008942
# (285250.0, 380000.0]    0.004471
# Name: Wage, dtype: float64

# %%
len(df[df.Club == 'Manchester United']['Nationality'].value_counts())
# Out:
# 13

# %%
s=df[(df.Nationality == 'Brazil')&(df.Club=='Juventus')]
s['Name'].unique()

# %%
df[df.Age > 35]['Club'].value_counts()
# Out:
# Club Atlético Huracán          4
# Hokkaido Consadole Sapporo     4
# Morecambe                      3
# San Martín de San Juan         3
# Gimnasia y Esgrima La Plata    3
#                               ..
# PEC Zwolle                     1
# SD Huesca                      1
# CD Tondela                     1
# Sporting de Charleroi          1
# Cerezo Osaka                   1
# Name: Club, Length: 212, dtype: int64

# %%
df[df.Nationality == 'Argentina']['Age'].value_counts(bins=4)
# Out:
# (22.25, 28.5]      200
# (15.974, 22.25]    197
# (28.5, 34.75]      128
# (34.75, 41.0]       49
# Name: Age, dtype: int64

# %%
df[df.Nationality == 'Spain']['Age'].value_counts(normalize=True)
# Out:
# 21    0.117735
# 22    0.095380
# 20    0.077496
# 23    0.071535
# 25    0.064083
# 27    0.062593
# 24    0.059613
# 28    0.053651
# 26    0.053651
# 29    0.047690
# 19    0.047690
# 18    0.038748
# 30    0.038748
# 31    0.032787
# 32    0.032787
# 33    0.031297
# 34    0.022355
# 17    0.013413
# 35    0.011923
# 36    0.010432
# 37    0.008942
# 39    0.002981
# 16    0.002981
# 38    0.001490
# Name: Age, dtype: float64

# %%
df.groupby(['Club','Nationality']).groups
# Out:
# {(' SSV Jahn Regensburg', 'Denmark'): Int64Index([4154], dtype='int64'),
#  (' SSV Jahn Regensburg',
#   'Germany'): Int64Index([ 1642,  2284,  2374,  2401,  2575,  2583,  2850,  3418,  3908,
#               3989,  5151,  5177,  5525,  6070,  7173,  8905,  9061, 10825,
#              12482],
#             dtype='int64'),
#  (' SSV Jahn Regensburg', 'Kosovo'): Int64Index([7477], dtype='int64'),
#  (' SSV Jahn Regensburg', 'Lithuania'): Int64Index([6679], dtype='int64'),
#  (' SSV Jahn Regensburg', 'Morocco'): Int64Index([5885], dtype='int64'),
#  (' SSV Jahn Regensburg', 'Poland'): Int64Index([2868], dtype='int64'),
#  ('1. FC Heidenheim 1846',
#   'Germany'): Int64Index([ 1060,  1805,  1978,  2050,  2066,  2926,  3584,  3605,  4312,
#               4457,  4783,  6818,  7160,  7166,  7460,  9475, 10052, 10565,
#              11217, 12236],
#             dtype='int64'),
#  ('1. FC Kaiserslautern', 'Canada'): Int64Index([4413], dtype='int64'),
#  ('1. FC Kaiserslautern',
# ...

# %%
grouped_df = df.groupby(['Club']).sum()
display(grouped_df)
# Out:
#                        Unnamed: 0  Age     Value    Wage  Crossing  Finishing  \
# Club
#  SSV Jahn Regensburg       129124  609  15195000   90000      1104        944
# 1. FC Heidenheim 1846      117834  473  18290000   76000       961        860
# 1. FC Kaiserslautern       167351  544  11195000   33000      1106        918
# 1. FC Köln                  54865  225  46810000   92000       444        357
# 1. FC Magdeburg            116731  515  57525000   84000       948        903
# ...                           ...  ...       ...     ...       ...        ...
# Zagłębie Sosnowiec         220803  656   6815000   27000      1161       1007
# Çaykur Rizespor            119137  557  27515000  118000      1110        921
# Örebro SK                  224465  622   8465000   36000      1114        974
# Östersunds FK              136103  478  11030000   39000       944        805
# Śląsk Wrocław              172358  628   9170000   50000      1058       1054
#
# ...

# %%
grouped_df.loc['Ajax']['Wage']
# Out:
# 158000

# %%
grouped_df = df.groupby(['Club'])['Wage'].sum()
display(grouped_df)
# Out:
# Club
#  SSV Jahn Regensburg      90000
# 1. FC Heidenheim 1846     76000
# 1. FC Kaiserslautern      33000
# 1. FC Köln                92000
# 1. FC Magdeburg           84000
#                           ...
# Zagłębie Sosnowiec        27000
# Çaykur Rizespor          118000
# Örebro SK                 36000
# Östersunds FK             39000
# Śląsk Wrocław             50000
# Name: Wage, Length: 650, dtype: int64

# %%
grouped_df = df.groupby(['Position'])['Wage'].sum()
grouped_df.columns = ['Position','Wage']
df1 = pd.DataFrame(grouped_df)
#print(grouped_df)
df1[df1.Wage > 5000000]
# Out:
#               Wage
# Position
# CAM        5500000
# CB         7476000
# CM         6194000
# GK         8784000
# LB         6096000
# LM         5440000
# RB         5034000
# RM         5098000
# ST        11873000

# %%
s=df.groupby(['Nationality'])[['Wage','Age','ShotPower']].mean()
print(s)
# Out:
#                      Wage        Age  ShotPower
# Nationality
# Afghanistan   1250.000000  22.500000  53.750000
# Albania       5931.034483  23.689655  54.551724
# Algeria      15810.810811  27.027027  56.567568
# Andorra       1000.000000  28.000000  58.000000
# Angola        7100.000000  24.700000  63.700000
# ...                   ...        ...        ...
# Uzbekistan    9000.000000  29.500000  71.500000
# Venezuela     6611.111111  23.638889  57.222222
# Wales         9529.411765  24.754902  48.558824
# Zambia        2833.333333  21.833333  66.833333
# Zimbabwe      5000.000000  26.555556  62.888889
#
# [156 rows x 3 columns]

# %%
df.groupby(['Nationality'])[['Wage','Age','ShotPower']].mean().sort_values(['Wage'],ascending=False).head(10)
# Out:
#                             Wage        Age  ShotPower
# Nationality
# Dominican Republic  71000.000000  23.000000  75.500000
# Egypt               35545.454545  25.818182  59.363636
# Gabon               28900.000000  26.400000  56.900000
# Croatia             26722.222222  24.819444  54.305556
# Equatorial Guinea   25666.666667  28.000000  55.333333
# Belgium             20024.390244  24.030488  56.390244
# Ecuador             18333.333333  24.619048  60.666667
# Uruguay             17590.361446  26.771084  56.192771
# Brazil              17371.158392  27.898345  58.203310
# Algeria             15810.810811  27.027027  56.567568

# %%
df.loc[df['Nationality'] == 'Dominican Republic'][['Name','Club','Wage','Age','ShotPower']]
# Out:
#             Name         Club    Wage  Age  ShotPower
# 291      Mariano  Real Madrid  140000   24         85
# 6279  L. Quezada   Córdoba CF    2000   22         66

# %%
df.groupby(['Position'])[['Wage','Value']].mean().sort_values(['Value'],ascending=False)
# Out:
#                    Wage         Value
# Position
# LF         75125.000000  2.736250e+07
# RF        119000.000000  2.636583e+07
# LAM        61000.000000  1.324583e+07
# RAM        11800.000000  8.345000e+06
# LS         15421.487603  5.848430e+06
# LCM        13497.854077  4.318090e+06
# RCM        13504.166667  4.217604e+06
# RS         13482.456140  3.645833e+06
# LW         12169.421488  3.603099e+06
# RW         13822.784810  3.495738e+06
# LDM        10243.243243  3.369459e+06
# RCB        11270.334928  3.009055e+06
# CAM         8688.783570  2.963199e+06
# RDM        11282.608696  2.692717e+06
# LCB         9753.056235  2.636516e+06
# LM          7472.527473  2.466174e+06
# ST          7852.513228  2.157252e+06
# RM          6655.352480  2.138734e+06
# LWB         5783.333333  1.931333e+06
# CF          4862.745098  1.848627e+06
# CDM         7121.562952  1.658900e+06
# CM          5805.060918  1.617465e+06
# RWB         6000.000000  1.555571e+06
# ...

# %%
df.groupby(['Nationality'])[['Club','Name']].nunique()
# Out:
#              Club  Name
# Nationality
# Afghanistan     4     4
# Albania        26    29
# Algeria        33    37
# Andorra         1     1
# Angola          9    10
# ...           ...   ...
# Uzbekistan      2     2
# Venezuela      34    36
# Wales          56   101
# Zambia          5     6
# Zimbabwe        8     9
#
# [156 rows x 2 columns]

# %%
df.groupby(['Club'])['Name'].count()
# Out:
# Club
#  SSV Jahn Regensburg     24
# 1. FC Heidenheim 1846    20
# 1. FC Kaiserslautern     23
# 1. FC Köln               10
# 1. FC Magdeburg          21
#                          ..
# Zagłębie Sosnowiec       25
# Çaykur Rizespor          22
# Örebro SK                26
# Östersunds FK            20
# Śląsk Wrocław            24
# Name: Name, Length: 650, dtype: int64

# %%
df.groupby(['Club'])['Dribbling'].median()
# Out:
# Club
#  SSV Jahn Regensburg     57.5
# 1. FC Heidenheim 1846    59.5
# 1. FC Kaiserslautern     54.0
# 1. FC Köln               60.5
# 1. FC Magdeburg          53.0
#                          ...
# Zagłębie Sosnowiec       58.0
# Çaykur Rizespor          62.0
# Örebro SK                55.0
# Östersunds FK            61.5
# Śląsk Wrocław            54.5
# Name: Dribbling, Length: 650, dtype: float64

# %%
df.groupby(['Club'])['Strength'].max()
# Out:
# Club
#  SSV Jahn Regensburg     92
# 1. FC Heidenheim 1846    86
# 1. FC Kaiserslautern     85
# 1. FC Köln               76
# 1. FC Magdeburg          86
#                          ..
# Zagłębie Sosnowiec       84
# Çaykur Rizespor          81
# Örebro SK                85
# Östersunds FK            88
# Śląsk Wrocław            85
# Name: Strength, Length: 650, dtype: int64

# %%
s=pd.DataFrame(df.groupby(['Club'])['Wage'].agg(['mean','median']))
len(s[s['mean'] == s['median']])
s[s['mean'] == s['median']].sort_values(['mean','median'],ascending=False)
# Out:
#                            mean  median
# Club
# Cruzeiro                13000.0   13000
# Göztepe SK               7000.0    7000
# Brøndby IF               6000.0    6000
# 1. FC Magdeburg          4000.0    4000
# CD Feirense              4000.0    4000
# Sunderland               4000.0    4000
# Northampton Town         2500.0    2500
# AJ Auxerre               2000.0    2000
# Benevento                2000.0    2000
# CD Tondela               2000.0    2000
# Grimsby Town             2000.0    2000
# Heracles Almelo          2000.0    2000
# Jeonnam Dragons          2000.0    2000
# Kashiwa Reysol           2000.0    2000
# Philadelphia Union       2000.0    2000
# Pohang Steelers          2000.0    2000
# Stade Brestois 29        2000.0    2000
# FC Metz                  1500.0    1500
# AEK Athens               1000.0    1000
# Bohemian FC              1000.0    1000
# Boyacá Chicó FC          1000.0    1000
# Bray Wanderers           1000.0    1000
# ...

# %%
df.groupby(['Club'])['Wage'].sum()['Chelsea']
# Out:
# 2035000

# %%
df[(df.Nationality == 'Argentina')&(df.Age == 30)].sort_values('Wage',ascending=False)
# Out:
#       Unnamed: 0             Name  Age Nationality  \
# 23            23        S. Agüero   30   Argentina
# 38            38       G. Higuaín   30   Argentina
# 89            89      N. Otamendi   30   Argentina
# 140          140         A. Gómez   30   Argentina
# 1286        1321         C. Yacob   30   Argentina
# 133          133        E. Banega   30   Argentina
# 522          526        L. Pratto   30   Argentina
# 218          218        N. Gaitán   30   Argentina
# 833          844      D. González   30   Argentina
# 1468        1521          G. Sara   30   Argentina
# 1337        1376        J. Forlín   30   Argentina
# 1501        1557      C. Menéndez   30   Argentina
# 2113        2216        F. Mattia   30   Argentina
# 2660        2781           A. Niz   30   Argentina
# 3227        3360       J. Amoroso   30   Argentina
# 1879        1970        M. Cahais   30   Argentina
# 2609        2727          G. Díaz   30   Argentina
# ...

# %%
s=df[(df.Nationality == 'Argentina')&(df.Club == 'FC Barcelona')].groupby(['Club'])[['Strength', 'Balance']].apply(max)
print(s)
# Out:
#               Strength  Balance
# Club
# FC Barcelona        59       95

# %%
pivot = df.loc[df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])].pivot_table(
values=['Wage'],
index=['Nationality'],
columns=['Club'],
aggfunc='sum',
margins=True,
fill_value=0)
display(pivot)
# Out:
#                            Wage                                         \
# Club               FC Barcelona Juventus Manchester United Real Madrid
# Nationality
# Argentina                565000   205000            206000           0
# Belgium                  110000        0            230000      240000
# Bosnia Herzegovina            0   180000                 0           0
# Brazil                   465000   335000             91000      570000
# Chile                    205000        0            215000           0
# Costa Rica                    0        0                 0      195000
# Croatia                  260000   160000                 0      420000
# Dominican Republic            0        0                 0      140000
# Ecuador                       0        0            120000           0
# England                       0        0            478000           0
# France                   495000   145000            375000      459000
# ...

# %%
df2 = df.pivot_table(columns = 'Position', index = 'Club', values = 'Wage', aggfunc = 'max')
print(df2)
print(df2.loc['Manchester City']['GK'])
# Out:
# Position                   CAM       CB      CDM      CF      CM       GK  \
# Club
#  SSV Jahn Regensburg       NaN   5000.0   5000.0     NaN  4000.0   5000.0
# 1. FC Heidenheim 1846   5000.0   7000.0      NaN     NaN  1000.0   4000.0
# 1. FC Kaiserslautern       NaN   1000.0   1000.0     NaN     NaN   1000.0
# 1. FC Köln                 NaN   1000.0  10000.0     NaN  3000.0  25000.0
# 1. FC Magdeburg            NaN   7000.0      NaN  4000.0     NaN   6000.0
# ...                        ...      ...      ...     ...     ...      ...
# Zagłębie Sosnowiec      2000.0   1000.0   1000.0     NaN     NaN   1000.0
# Çaykur Rizespor        11000.0  11000.0  13000.0     NaN     NaN   3000.0
# Örebro SK                  NaN   2000.0      NaN     NaN  1000.0   2000.0
# Östersunds FK           1000.0   1000.0      NaN  3000.0  8000.0   1000.0
# Śląsk Wrocław              NaN   1000.0   3000.0     NaN  1000.0   2000.0
#
# ...

# %%
pivot = df.loc[df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])].pivot_table(values=['Name'],
index=['Nationality'],
columns=['Club'],
aggfunc='count',
fill_value=0)
display(pivot)
# Out:
#                            Name
# Club               FC Barcelona Juventus Manchester United Real Madrid
# Nationality
# Argentina                     1        1                 2           0
# Belgium                       1        0                 1           1
# Bosnia Herzegovina            0        1                 0           0
# Brazil                        2        2                 1           2
# Chile                         1        0                 1           0
# Costa Rica                    0        0                 0           1
# Croatia                       1        1                 0           1
# Dominican Republic            0        0                 0           1
# Ecuador                       0        0                 1           0
# England                       0        0                 6           0
# France                        3        1                 2           3
# Germany                       1        1                 0           1
# ...

# %%
pivot.loc['Argentina']['Name']['Manchester United']
# Out:
# 2

# %%
df3= df.pivot_table(values=['Name'],index=['Club'],columns=['Position'],aggfunc='count',margins=True,fill_value=0)
print(df3)
mean_GK = df3.loc['All']['Name']['GK']
print(len(df3.index))
print(mean_GK)
# Out:
#                       Name                                                 \
# Position               CAM    CB  CDM  CF    CM    GK LAM    LB  LCB  LCM
# Club
#  SSV Jahn Regensburg     0     5    1   0     2     3   0     2    0    0
# 1. FC Heidenheim 1846    1     3    0   0     1     2   0     2    1    0
# 1. FC Kaiserslautern     0     3    3   0     0     3   0     2    1    0
# 1. FC Köln               0     1    1   0     2     3   0     0    0    0
# 1. FC Magdeburg          0     4    0   1     0     3   0     1    1    1
# ...                    ...   ...  ...  ..   ...   ...  ..   ...  ...  ...
# Çaykur Rizespor          1     2    5   0     0     3   0     2    1    0
# Örebro SK                0     4    0   0     1     3   0     0    1    1
# Östersunds FK            1     1    0   1     3     3   0     2    1    1
# Śląsk Wrocław            0     1    3   0     1     3   0     2    1    0
# All                    633  1403  691  51  1067  1641   6  1002  409  233
#
# ...

# %%
df4=df.pivot_table(values=['Wage'],
index=['Club'],
columns=['Nationality'],
aggfunc='sum',
fill_value=0)
a=df4.loc['AS Monaco']['Wage']['Russia']
print(df4)
print(a)
# Out:
#                              Wage                                 \
# Nationality           Afghanistan Albania Algeria Andorra Angola
# Club
#  SSV Jahn Regensburg            0       0       0       0      0
# 1. FC Heidenheim 1846           0       0       0       0      0
# 1. FC Kaiserslautern            0       0       0       0      0
# 1. FC Köln                      0       0       0       0      0
# 1. FC Magdeburg                 0       0       0       0      0
# ...                           ...     ...     ...     ...    ...
# Zagłębie Sosnowiec              0       0       0       0   1000
# Çaykur Rizespor                 0       0       0       0      0
# Örebro SK                       0    1000       0       0      0
# Östersunds FK                   0       0       0       0      0
# Śląsk Wrocław                   0       0       0       0      0
#
#                                                                              \
# ...

# %%
df5=df.pivot_table(values=['SprintSpeed'],
index=['Position'],
columns=['Club'],
aggfunc='mean',
fill_value=0)
#margins=True)
type(df5)
#rint(df5)
#df5[df5.Position == 'ST']
pivot = df.loc[df['Position'].isin(['ST'])].pivot_table(['SprintSpeed'], index=['Club'], aggfunc='mean', fill_value=0)
print(pivot.loc['Sydney FC'])
print(pivot.loc['Melbourne Victory'])
print(pivot.loc['Vitória'])
print(pivot.loc['Toronto FC'])
print(pivot.loc['Arsenal'])
print(pivot.loc['CD Lugo'])
# Out:
# SprintSpeed    88.0
# Name: Sydney FC, dtype: float64
# SprintSpeed    81.0
# Name: Melbourne Victory, dtype: float64
# SprintSpeed    91.0
# Name: Vitória, dtype: float64
# SprintSpeed    81.75
# Name: Toronto FC, dtype: float64
# SprintSpeed    83.0
# Name: Arsenal, dtype: float64
# SprintSpeed    87.0
# Name: CD Lugo, dtype: float64
