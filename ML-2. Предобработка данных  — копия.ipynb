# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('data_flats.csv',sep=";")
pd.options.display.max_rows=60
data.head()
# Out:
#    id  full_sq  life_sq  floor           sub_area  preschool_quota  \
# 0   1       43     27.0    4.0           Bibirevo           5001.0
# 1   2       34     19.0    3.0  Nagatinskij Zaton           3119.0
# 2   3       43     29.0    2.0     Tekstil'shhiki           1463.0
# 3   4       89     50.0    9.0             Mitino           6839.0
# 4   5       77     77.0    4.0          Basmannoe           3240.0
#
#    preschool_education_centers_raion  school_quota  \
# 0                                  5       11065.0
# 1                                  5        6237.0
# 2                                  4        5580.0
# 3                                  9       17063.0
# 4                                  7        7770.0
#
#    school_education_centers_raion  school_education_centers_top_20_raion  ...  \
# 0                               5                                      0  ...
# 1                               8                                      0  ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30469 entries, 0 to 30468
# Data columns (total 56 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     30469 non-null  int64
#  1   full_sq                                30469 non-null  int64
#  2   life_sq                                24086 non-null  float64
#  3   floor                                  30302 non-null  float64
#  4   sub_area                               30469 non-null  object
#  5   preschool_quota                        23781 non-null  float64
#  6   preschool_education_centers_raion      30469 non-null  int64
#  7   school_quota                           23784 non-null  float64
#  8   school_education_centers_raion         30469 non-null  int64
#  9   school_education_centers_top_20_raion  30469 non-null  int64
# ...

# %%
test_data = pd.DataFrame([[1, 2, np.nan], [3, np.nan, 4],
                          [0, 1, 2]], columns=['one', 'two', 'three'])

# %%
test_data.isna()
# Out:
#      one    two  three
# 0  False  False   True
# 1  False   True  False
# 2  False  False  False

# %%
test_data.dropna(axis=0)
# Out:
#    one  two  three
# 2    0  1.0    2.0

# %%
test_data = pd.DataFrame([[1, 2, np.nan], [3, np.nan, 4],
                          [0, 1, 2]], columns=['one', 'two', 'three'])

# %%
test_data.fillna(-1)
# Out:
#    one  two  three
# 0    1  2.0   -1.0
# 1    3 -1.0    4.0
# 2    0  1.0    2.0

# %%
vis_data = pd.read_csv("train.csv", encoding = 'ISO-8859-1', low_memory = False)
vis_data.head()
vis_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250306 entries, 0 to 250305
# Data columns (total 34 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   ticket_id                   250306 non-null  int64
#  1   agency_name                 250306 non-null  object
#  2   inspector_name              250306 non-null  object
#  3   violator_name               250272 non-null  object
#  4   violation_street_number     250306 non-null  float64
#  5   violation_street_name       250306 non-null  object
#  6   violation_zip_code          0 non-null       float64
#  7   mailing_address_str_number  246704 non-null  float64
#  8   mailing_address_str_name    250302 non-null  object
#  9   city                        250306 non-null  object
#  10  state                       250213 non-null  object
#  11  zip_code                    250305 non-null  object
# ...

# %%
value=vis_data['state'].value_counts().idxmax()
value
# Out:
# 'MI'

# %%
vis_data['state']=vis_data['state'].fillna(value)

# %%
vis_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250306 entries, 0 to 250305
# Data columns (total 34 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   ticket_id                   250306 non-null  int64
#  1   agency_name                 250306 non-null  object
#  2   inspector_name              250306 non-null  object
#  3   violator_name               250272 non-null  object
#  4   violation_street_number     250306 non-null  float64
#  5   violation_street_name       250306 non-null  object
#  6   violation_zip_code          0 non-null       float64
#  7   mailing_address_str_number  246704 non-null  float64
#  8   mailing_address_str_name    250302 non-null  object
#  9   city                        250306 non-null  object
#  10  state                       250306 non-null  object
#  11  zip_code                    250305 non-null  object
# ...

# %%
vis_data = pd.read_csv("train.csv", encoding = 'ISO-8859-1', low_memory = False)
value=vis_data['state'].value_counts().idxmax()
vis_data['state']=vis_data['state'].fillna(value)
result=value

# %%
vis_data = pd.read_csv("train.csv", encoding = 'ISO-8859-1', low_memory = False)
# Напишите ваш код ниже
result = vis_data.state.fillna(vis_data.state.mode()[0])

# %%
data = pd.read_csv('data_flats.csv',sep=";")
pd.options.display.max_rows=60
data.head()
# Out:
#    id  full_sq  life_sq  floor           sub_area  preschool_quota  \
# 0   1       43     27.0    4.0           Bibirevo           5001.0
# 1   2       34     19.0    3.0  Nagatinskij Zaton           3119.0
# 2   3       43     29.0    2.0     Tekstil'shhiki           1463.0
# 3   4       89     50.0    9.0             Mitino           6839.0
# 4   5       77     77.0    4.0          Basmannoe           3240.0
#
#    preschool_education_centers_raion  school_quota  \
# 0                                  5       11065.0
# 1                                  5        6237.0
# 2                                  4        5580.0
# 3                                  9       17063.0
# 4                                  7        7770.0
#
#    school_education_centers_raion  school_education_centers_top_20_raion  ...  \
# 0                               5                                      0  ...
# 1                               8                                      0  ...
# ...

# %%
data=data.dropna()
data
# Out:
#           id  full_sq  life_sq  floor           sub_area  preschool_quota  \
# 0          1       43     27.0    4.0           Bibirevo           5001.0
# 1          2       34     19.0    3.0  Nagatinskij Zaton           3119.0
# 2          3       43     29.0    2.0     Tekstil'shhiki           1463.0
# 4          5       77     77.0    4.0          Basmannoe           3240.0
# 6          7       25     14.0   10.0         Sokol'niki            933.0
# ...      ...      ...      ...    ...                ...              ...
# 30461  30466       56     29.0   13.0   Severnoe Tushino           4116.0
# 30462  30467       56     51.0   19.0           Sviblovo           2057.0
# 30465  30470       86     59.0    3.0           Tverskoe           1874.0
# 30467  30472       64     32.0    5.0       Obruchevskoe           2372.0
# 30468  30473       43     28.0    1.0        Novogireevo           2215.0
#
#        preschool_education_centers_raion  school_quota  \
# ...

# %%
test_data = pd.DataFrame([[1, 2, np.nan], [3, np.nan, 417],
                          [0, 10, -212]], columns=['one', 'two', 'three'])

# %%
test_data
# Out:
#    one   two  three
# 0    1   2.0    NaN
# 1    3   NaN  417.0
# 2    0  10.0 -212.0

# %%
from sklearn.preprocessing import MinMaxScaler
test_data=test_data.fillna(0)

# %%
scaler = MinMaxScaler()
scaler.fit_transform(test_data)
# Out:
# array([[0.33333333, 0.2       , 0.33704293],
#        [1.        , 0.        , 1.        ],
#        [0.        , 1.        , 0.        ]])

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit_transform(test_data)
# Out:
# array([[-0.26726124, -0.46291005, -0.26151831],
#        [ 1.33630621, -0.9258201 ,  1.33438124],
#        [-1.06904497,  1.38873015, -1.07286293]])

# %%
vis_data = pd.read_csv("train.csv", encoding = 'ISO-8859-1', low_memory = False)
vis_data.comuns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-334fa4836bcf> in <module>
#       1 vis_data = pd.read_csv("train.csv", encoding = 'ISO-8859-1', low_memory = False)
# ----> 2 vis_data.comuns
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'comuns'

# %%
vis_data.columns.values
# Out:
# array(['ticket_id', 'agency_name', 'inspector_name', 'violator_name',
#        'violation_street_number', 'violation_street_name',
#        'violation_zip_code', 'mailing_address_str_number',
#        'mailing_address_str_name', 'city', 'state', 'zip_code',
#        'non_us_str_code', 'country', 'ticket_issued_date', 'hearing_date',
#        'violation_code', 'violation_description', 'disposition',
#        'fine_amount', 'admin_fee', 'state_fee', 'late_fee',
#        'discount_amount', 'clean_up_cost', 'judgment_amount',
#        'payment_amount', 'balance_due', 'payment_date', 'payment_status',
#        'collection_status', 'grafitti_status', 'compliance_detail',
#        'compliance'], dtype=object)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit_transform(vis_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-ed75e38e3eaa> in <module>
#       1 from sklearn.preprocessing import StandardScaler
#       2 scaler = StandardScaler()
# ----> 3 scaler.fit_transform(vis_data)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     688         if y is None:
#     689             # fit method of arity 1 (unsupervised transformation)
# --> 690             return self.fit(X, **fit_params).transform(X)
#     691         else:
#     692             # fit method of arity 2 (supervised transformation)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y)
#     665         # Reset internal state before fitting
#     666         self._reset()
# --> 667         return self.partial_fit(X, y)
#     668
# ...

# %%
vis_data = pd.read_csv("train.csv", encoding = 'ISO-8859-1', low_memory = False)
balance = np.array(vis_data['balance_due']).reshape((int(len(vis_data)/2), 2))
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
reshaped_balance = np.reshape(balance, (len(balance), -1))
balans_st=scaler.fit_transform(reshaped_balance)
np.min(balans_st)

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
vis_data=pd.read_csv("train.csv",
                     encoding = 'ISO-8859-1',
                     low_memory = False)
vis_data.head(2)

# %%
vis_data.balance_due[vis_data.balance_due > 0].hist(bins=10)

# %%
np.log(vis_data.balance_due[vis_data.balance_due > 0]).hist(bins=10)

# %%
np.sqrt(vis_data.balance_due[vis_data.balance_due > 0]).hist()

# %%
np.log(vis_data.balance_due[vis_data.balance_due >= 0]+1).hist(bins=10)

# %%
import seaborn as sns

# %%
corr = vis_data.drop(['violation_zip_code', 'payment_amount', 
                      'clean_up_cost', 
                      'violation_street_number'], axis=1).\
                dropna(axis=1).\
                corr()
cmap = sns.diverging_palette(5, 250, as_cmap=True)

def magnify():
    return [dict(selector="th",
                 props=[("font-size", "9pt")]),
            dict(selector="td",
                 props=[('padding', "0em 0em")]),
            dict(selector="th:hover",
                 props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover",
                 props=[('max-width', '200px'),
                        ('font-size', '12pt')])
]

corr.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '90px', 'font-size': '15pt'})\
    .set_caption("Hover to magify")\
    .set_precision(2)\
    .set_table_styles(magnify())
# Out:
# <style  type="text/css" >
#     #T_27fcfbdc_e632_11ea_919f_c860006e9dc7 th {
#           font-size: 9pt;
#     }    #T_27fcfbdc_e632_11ea_919f_c860006e9dc7 td {
#           padding: 0em 0em;
#     }    #T_27fcfbdc_e632_11ea_919f_c860006e9dc7 th:hover {
#           font-size: 12pt;
#     }    #T_27fcfbdc_e632_11ea_919f_c860006e9dc7 tr:hover td:hover {
#           max-width: 200px;
#           font-size: 12pt;
#     }    #T_27fcfbdc_e632_11ea_919f_c860006e9dc7row0_col0 {
#             background-color:  #4479bb;
#             color:  #000000;
#             max-width:  90px;
#             font-size:  15pt;
#         }    #T_27fcfbdc_e632_11ea_919f_c860006e9dc7row0_col1 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  90px;
#             font-size:  15pt;
#         }    #T_27fcfbdc_e632_11ea_919f_c860006e9dc7row0_col2 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  90px;
# ...

# %%
vis_data = pd.read_csv("train.csv", encoding = 'ISO-8859-1', low_memory = False)
balance = np.array(vis_data['balance_due']).reshape((int(len(vis_data)/2), 2))
balanc_sqrt=np.sqrt(vis_data.balance_due[vis_data.balance_due > 0])
balanc_sqrt_mean=balanc_sqrt.mean()
balanc_sqrt_median=balanc_sqrt.median()
balanc_sqrt_mean-balanc_sqrt_median
# Out:
# -0.4525960609393067

# %%
data = pd.read_csv('data_flats.csv',sep=";")
pd.options.display.max_rows=60
data.head(20)
#data.sub_area.value_counts()
#districts=['Basmannoe','Lefortovo','Perovo','Bogorodskoe']
# Out:
#     id  full_sq  life_sq  floor           sub_area  preschool_quota  \
# 0    1       43     27.0    4.0           Bibirevo           5001.0
# 1    2       34     19.0    3.0  Nagatinskij Zaton           3119.0
# 2    3       43     29.0    2.0     Tekstil'shhiki           1463.0
# 3    4       89     50.0    9.0             Mitino           6839.0
# 4    5       77     77.0    4.0          Basmannoe           3240.0
# 5    6       67     46.0   14.0     Nizhegorodskoe            852.0
# 6    7       25     14.0   10.0         Sokol'niki            933.0
# 7    8       44     44.0    5.0           Bibirevo           5001.0
# 8    9       42     27.0    5.0            Koptevo           3272.0
# 9   10       36     21.0    9.0            Kuncevo           4050.0
# 10  11       36     19.0   12.0   Kosino-Uhtomskoe           3848.0
# 11  12       38     19.0   11.0  Zapadnoe Degunino           1503.0
# 12  13       43     28.0    4.0            Kuncevo           4050.0
# ...

# %%
new_data=pd.DataFrame(data[data['sub_area'].isin(districts)])
ax = sns.boxplot(x=new_data["price_doc"],y=new_data["sub_area"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-55d9ae702a60> in <module>
# ----> 1 new_data=pd.DataFrame(data[data['sub_area'].isin(districts)])
#       2 ax = sns.boxplot(x=new_data["price_doc"],y=new_data["sub_area"])
#
# NameError: name 'districts' is not defined

# %%
import numpy as np
import pandas as pd
# %matplotlib inline

vis_data = pd.read_csv("train.csv", 
                       encoding = 'ISO-8859-1', 
                       low_memory = False)
vis_data = pd.read_csv("train.csv", encoding = 'ISO-8859-1', low_memory = False)
vis_data = vis_data.drop(['violation_zip_code', 'clean_up_cost'], axis=1)
latlons = pd.read_csv("latlons.csv")
vis_data = pd.concat([vis_data, latlons], axis=1)

# %%
from sklearn.preprocessing import PolynomialFeatures

pf = PolynomialFeatures(2)
poly_features = pf.fit_transform(vis_data[['balance_due', 'payment_amount']])
poly_features
poly_features.shape
# Out:
# (250306, 6)

# %%
vis_data.city.value_counts()
# Out:
# DETROIT          136936
# SOUTHFIELD        13436
# Detroit           10496
# detroit            4183
# DEARBORN           3637
#                   ...
# 48037                 1
# ORMOND BEACH          1
# CLINTONTWP            1
# An Arbor              1
# Beverly hills         1
# Name: city, Length: 5184, dtype: int64

# %%
vis_data.city=vis_data.city.apply(lambda x: x.lower())

# %%
vis_data.city.value_counts()
# Out:
# detroit             151621
# southfield           14760
# dearborn              4017
# farmington hills      2508
# oak park              2432
#                      ...
# powder springs           1
# belleair beach           1
# rosedale ct              1
# logan                    1
# addison  twp             1
# Name: city, Length: 4324, dtype: int64

# %%
vis_data.head(10)
# Out:
#    ticket_id                                     agency_name  \
# 0      22056  Buildings, Safety Engineering & Env Department
# 1      27586  Buildings, Safety Engineering & Env Department
# 2      22062  Buildings, Safety Engineering & Env Department
# 3      22084  Buildings, Safety Engineering & Env Department
# 4      22093  Buildings, Safety Engineering & Env Department
# 5      22046  Buildings, Safety Engineering & Env Department
# 6      18738  Buildings, Safety Engineering & Env Department
# 7      18735  Buildings, Safety Engineering & Env Department
# 8      18733  Buildings, Safety Engineering & Env Department
# 9      28204  Buildings, Safety Engineering & Env Department
#
#      inspector_name                         violator_name  \
# 0   Sims, Martinzie     INVESTMENT INC., MIDWEST MORTGAGE
# 1  Williams, Darrin              Michigan, Covenant House
# 2   Sims, Martinzie                       SANDERS, DERRON
# ...

# %%
vis_data['distance'][vis_data['distance']<100].hist()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'distance'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-4bb20824f1c8> in <module>
# ...
